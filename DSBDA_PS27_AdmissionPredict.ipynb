# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Admission_Predict.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
duplicated = df.duplicated().sum()
if duplicated:
  print("Duplicated rows :{}".format(duplicated))
else:
  print("No duplicates")
# Out:
# No duplicates

# %%
#df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
#df.fillna(method="ffill", inplace=True)

# %%
for i in range(1,8):
  corr = df['Chance of Admit '].corr(df.iloc[:,i])
  print("Correlation between Chance of Admit and column", i,"is :", corr )
# Out:
# Correlation between Chance of Admit and column 1 is : 0.8026104595903499
# Correlation between Chance of Admit and column 2 is : 0.7915939869351049
# Correlation between Chance of Admit and column 3 is : 0.7112502503917218
# Correlation between Chance of Admit and column 4 is : 0.6757318583886716
# Correlation between Chance of Admit and column 5 is : 0.6698887920106936
# Correlation between Chance of Admit and column 6 is : 0.8732890993553001
# Correlation between Chance of Admit and column 7 is : 0.5532021370190395

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df[['CGPA']]
y = df[['Chance of Admit ']]

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x,y)
print(f"Coefficient of Determination: {r_sq}")
# Out:
# Coefficient of Determination: 0.7626338510527915

# %%
x_new = pd.DataFrame(
    {
        "CGPA": ['8.43', '9.24', '9.89', '7.81']
    }
)
y_pred = model.predict(x_new)
print(f"Predicted response:\n {y_pred}")
# Out:
# Predicted response:
#  [[0.68907048]
#  [0.85823674]
#  [0.99398744]
#  [0.5595852 ]]

# %%
#Create data subsets by making classes for Chances of admit.(e.g. Not Admitted, might get admitted, Admitted)

# %%
#Merge two subsets

# %%
df.sort_values(by="GRE Score", ascending=False)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 202         203        340          120                  5  4.5   4.5  9.91
# 33           34        340          114                  5  4.0   4.0  9.60
# 84           85        340          115                  5  4.5   4.5  9.45
# 143         144        340          120                  4  4.5   4.0  9.92
# 81           82        340          120                  4  5.0   5.0  9.50
# ..          ...        ...          ...                ...  ...   ...   ...
# 79           80        294           93                  1  1.5   2.0  7.36
# 272         273        294           95                  1  1.5   1.5  7.64
# 168         169        293           97                  2  2.0   4.0  7.80
# 377         378        290          100                  1  1.5   2.0  7.56
# 117         118        290          104                  4  2.0   2.5  7.46
#
#      Research  Chance of Admit
# ...

# %%
df.sort_values(by="TOEFL Score", ascending=False)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 25           26        340          120                  5  4.5   4.5  9.60
# 97           98        331          120                  3  4.0   4.0  8.96
# 81           82        340          120                  4  5.0   5.0  9.50
# 202         203        340          120                  5  4.5   4.5  9.91
# 203         204        334          120                  5  4.0   5.0  9.87
# ..          ...        ...          ...                ...  ...   ...   ...
# 78           79        296           95                  2  3.0   2.0  7.54
# 347         348        299           94                  1  1.0   1.0  7.34
# 28           29        295           93                  1  2.0   2.0  7.20
# 79           80        294           93                  1  1.5   2.0  7.36
# 368         369        298           92                  1  2.0   2.0  7.88
#
#      Research  Chance of Admit
# ...

# %%
df.sort_values(by="University Rating", ascending=False)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 193         194        336          118                  5  4.5   5.0  9.53
# 215         216        330          116                  5  5.0   4.5  9.36
# 286         287        336          118                  5  4.5   4.0  9.19
# 33           34        340          114                  5  4.0   4.0  9.60
# 34           35        331          112                  5  4.0   5.0  9.80
# ..          ...        ...          ...                ...  ...   ...   ...
# 79           80        294           93                  1  1.5   2.0  7.36
# 58           59        300           99                  1  3.0   2.0  6.80
# 28           29        295           93                  1  2.0   2.0  7.20
# 37           38        300          105                  1  1.0   2.0  7.80
# 377         378        290          100                  1  1.5   2.0  7.56
#
#      Research  Chance of Admit
# ...

# %%
transposed = df.transpose()
transposed
# Out:
#                       0       1       2       3       4       5       6    \
# Serial No.           1.00    2.00    3.00    4.00    5.00    6.00    7.00
# GRE Score          337.00  324.00  316.00  322.00  314.00  330.00  321.00
# TOEFL Score        118.00  107.00  104.00  110.00  103.00  115.00  109.00
# University Rating    4.00    4.00    3.00    3.00    2.00    5.00    3.00
# SOP                  4.50    4.00    3.00    3.50    2.00    4.50    3.00
# LOR                  4.50    4.50    3.50    2.50    3.00    3.00    4.00
# CGPA                 9.65    8.87    8.00    8.67    8.21    9.34    8.20
# Research             1.00    1.00    1.00    1.00    0.00    1.00    1.00
# Chance of Admit      0.92    0.76    0.72    0.80    0.65    0.90    0.75
#
#                       7      8       9    ...     390     391     392     393  \
# Serial No.           8.00    9.0   10.00  ...  391.00  392.00  393.00  394.00
# ...

# %%
melted = pd.melt(df, id_vars=['Serial No.'], value_vars=['GRE Score', 'TOEFL Score', 'CGPA'])
melted
# Out:
#       Serial No.   variable   value
# 0              1  GRE Score  337.00
# 1              2  GRE Score  324.00
# 2              3  GRE Score  316.00
# 3              4  GRE Score  322.00
# 4              5  GRE Score  314.00
# ...          ...        ...     ...
# 1195         396       CGPA    9.04
# 1196         397       CGPA    9.11
# 1197         398       CGPA    9.45
# 1198         399       CGPA    8.78
# 1199         400       CGPA    9.66
#
# [1200 rows x 3 columns]

# %%
cast = pd.pivot(melted, index='Serial No.', columns='variable', values='value')
cast
# Out:
# variable    CGPA  GRE Score  TOEFL Score
# Serial No.
# 1           9.65      337.0        118.0
# 2           8.87      324.0        107.0
# 3           8.00      316.0        104.0
# 4           8.67      322.0        110.0
# 5           8.21      314.0        103.0
# ...          ...        ...          ...
# 396         9.04      324.0        110.0
# 397         9.11      325.0        107.0
# 398         9.45      330.0        116.0
# 399         8.78      312.0        103.0
# 400         9.66      333.0        117.0
#
# [400 rows x 3 columns]
