# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset_Facebook.csv", delimiter=";")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photos = df[df['Type'] == "Photo"]
photos
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
links = df[df['Type'] == "Link"]
links
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
videos = df[df['Type'] == 'Video']
videos
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
subset1 = df[['Type', 'Category']]
subset1
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
subset2 = df[['like', 'share', 'Category']]
subset2
# Out:
#        like  share  Category
# 0      79.0   17.0         2
# 1     130.0   29.0         2
# 2      66.0   14.0         3
# 3    1572.0  147.0         2
# 4     325.0   49.0         2
# ..      ...    ...       ...
# 495    53.0   26.0         3
# 496    53.0   22.0         2
# 497    93.0   18.0         1
# 498    91.0   38.0         3
# 499    91.0   28.0         2
#
# [500 rows x 3 columns]

# %%
merged_subset = pd.merge(subset1, subset2,how='inner', sort=True)
merged_subset
# Out:
#         Type  Category   like  share
# 0      Photo         1  678.0   20.0
# 1      Photo         1    0.0    0.0
# 2      Photo         1   16.0    2.0
# 3      Photo         1  143.0   13.0
# 4      Photo         1   56.0   17.0
# ...      ...       ...    ...    ...
# 87145  Photo         3  105.0   46.0
# 87146  Photo         3  185.0   55.0
# 87147  Photo         3  125.0   41.0
# 87148  Photo         3   53.0   26.0
# 87149  Photo         3   91.0   38.0
#
# [87150 rows x 4 columns]

# %%
subset1.merge(subset2[['like', 'share', 'Category']])
# Out:
#         Type  Category    like  share
# 0      Photo         2    79.0   17.0
# 1      Photo         2   130.0   29.0
# 2      Photo         2  1572.0  147.0
# 3      Photo         2   325.0   49.0
# 4      Photo         2   152.0   33.0
# ...      ...       ...     ...    ...
# 87145  Photo         1   101.0    5.0
# 87146  Photo         1     5.0    2.0
# 87147  Photo         1    12.0    2.0
# 87148  Photo         1   128.0    9.0
# 87149  Photo         1    93.0   18.0
#
# [87150 rows x 4 columns]

# %%
df.sort_values(by='Page total likes', ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
transposed = df.transpose()
transposed
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
melted = pd.melt(df.reset_index(), id_vars='index', value_vars=['Type','Category', 'comment', 'like', 'share'])
melted
# Out:
#       index variable   value
# 0         0     Type   Photo
# 1         1     Type  Status
# 2         2     Type   Photo
# 3         3     Type   Photo
# 4         4     Type   Photo
# ...     ...      ...     ...
# 2495    495    share    26.0
# 2496    496    share    22.0
# 2497    497    share    18.0
# 2498    498    share    38.0
# 2499    499    share    28.0
#
# [2500 rows x 3 columns]

# %%
cast = pd.pivot(melted, index='index', columns='variable', values='value')
cast
# Out:
# variable Category    Type comment    like  share
# index
# 0               2   Photo       4    79.0   17.0
# 1               2  Status       5   130.0   29.0
# 2               3   Photo       0    66.0   14.0
# 3               2   Photo      58  1572.0  147.0
# 4               2   Photo      19   325.0   49.0
# ...           ...     ...     ...     ...    ...
# 495             3   Photo       5    53.0   26.0
# 496             2   Photo       0    53.0   22.0
# 497             1   Photo       4    93.0   18.0
# 498             3   Photo       7    91.0   38.0
# 499             2   Photo       0    91.0   28.0
#
# [500 rows x 5 columns]

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...
