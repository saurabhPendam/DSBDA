# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Admission_Predict.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
plt.hist(df['GRE Score'])
plt.xlabel('GRE Score')
plt.plot()
# Out:
# []

# %%
sns.histplot(df['CGPA'])
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
sns.barplot(y='Chance of Admit ', x='University Rating', data=df)
# Out:
# <Axes: xlabel='University Rating', ylabel='Chance of Admit '>

# %%
sns.lineplot(x='TOEFL Score', y='Chance of Admit ', data=df)
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Chance of Admit '>

# %%
sns.scatterplot(x="CGPA", y="Chance of Admit ", data=df)
# Out:
# <Axes: xlabel='CGPA', ylabel='Chance of Admit '>

# %%
sns.boxplot(y='SOP', x='LOR ', data=df)
# Out:
# <Axes: xlabel='LOR ', ylabel='SOP'>

# %%
df['University Rating'].unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
data = [ df['University Rating'].value_counts()[1],
        df['University Rating'].value_counts()[2],
        df['University Rating'].value_counts()[3],
        df['University Rating'].value_counts()[4],
        df['University Rating'].value_counts()[5]]
labels = ["1", "2", "3", "4", "5"]
plt.pie(data, labels=labels)
plt.show()
